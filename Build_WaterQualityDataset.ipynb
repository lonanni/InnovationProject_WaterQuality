# %% [markdown]
# # How to obtain a water quality dataset for the location and period of interest
#
# This example notebook explains how to obtain the data from DEFRA to start looking at water quality in any region of interest in the UK.

# %%
import numpy as np
import sys
import pandas as pd
import os

# %% [markdown]
# ## 1) Download necessary files
# #### for the nature of the dataset, this step cannot be automated
#
# At https://environment.data.gov.uk/water-quality/view/download/new you can find all the data that DEFRA has collected for the water quality in the UK since 2000.
# You will need to download the dataset year by year, for the time of interest.
# It is recommended to investigate each region separately since a vast amount of data has been collected.

# %% [markdown]
# Save the datasets in a directory.
# In my case, I download the Solent and South Downs datasets and the Cornwall and Devon from 2000 to 2025, i.e. region code SSD and DC.

# %% [markdown]
# ## 2) Create the dataset

# %%
dir_files = "./data/" # directory containing the datasets
start_year = 2000 
end_year = 2026
region_code = "DC" #change it for the region code of your region of interest

# %%
dfs = {} # initiate dictionary
df_to_conc = [] # initiate array

# Load the CSV into the dictionary & concatenate datasets

for year in range(start_year, end_year):
    file_path = f'{dir_files}{region_code}-{year}.csv'  
    dfs[year] = pd.read_csv(file_path, engine='python')
    df_to_conc.append(pd.read_csv(file_path, engine='python'))
    # Now that the datasets are loaded, you can remove the files.
    # This step is necessary if you want to work with github (files are too big to get pushed into the repository).
    # Comment out the next line if you want to keep the files on your machine
    #os.remove(file_path)

# %%
df_water = pd.concat(df_to_conc, ignore_index=True)

# %%
df_water
# Out:
#                                                        @id  \
# 0        http://environment.data.gov.uk/water-quality/d...
# 1        http://environment.data.gov.uk/water-quality/d...
# 2        http://environment.data.gov.uk/water-quality/d...
# 3        http://environment.data.gov.uk/water-quality/d...
# 4        http://environment.data.gov.uk/water-quality/d...
# ...                                                    ...
# 7308646  http://environment.data.gov.uk/water-quality/d...
# 7308647  http://environment.data.gov.uk/water-quality/d...
# 7308648  http://environment.data.gov.uk/water-quality/d...
# 7308649  http://environment.data.gov.uk/water-quality/d...
# 7308650  http://environment.data.gov.uk/water-quality/d...
#
#                                       sample.samplingPoint  \
# 0        http://environment.data.gov.uk/water-quality/i...
# 1        http://environment.data.gov.uk/water-quality/i...
# 2        http://environment.data.gov.uk/water-quality/i...
# 3        http://environment.data.gov.uk/water-quality/i...
# 4        http://environment.data.gov.uk/water-quality/i...
# ...                                                    ...
# 7308646  http://environment.data.gov.uk/water-quality/i...
# 7308647  http://environment.data.gov.uk/water-quality/i...
# 7308648  http://environment.data.gov.uk/water-quality/i...
# 7308649  http://environment.data.gov.uk/water-quality/i...
# 7308650  http://environment.data.gov.uk/water-quality/i...
#
#         sample.samplingPoint.notation              sample.samplingPoint.label  \
# 0                         SW-70110104                      RIVER LIM AT BEACH
# 1                         SW-70110104                      RIVER LIM AT BEACH
# 2                         SW-70110104                      RIVER LIM AT BEACH
# 3                         SW-70110104                      RIVER LIM AT BEACH
# 4                         SW-70110104                      RIVER LIM AT BEACH
# ...                               ...                                     ...
# 7308646                    SW-SSN1632  SSN1632 DICKFORD WATER AT FURSDON BARN
# 7308647                    SW-SSN1632  SSN1632 DICKFORD WATER AT FURSDON BARN
# 7308648                    SW-SSN1632  SSN1632 DICKFORD WATER AT FURSDON BARN
# 7308649                    SW-SSN1632  SSN1632 DICKFORD WATER AT FURSDON BARN
# 7308650                    SW-SSN1632  SSN1632 DICKFORD WATER AT FURSDON BARN
#
#         sample.sampleDateTime determinand.label  \
# 0         2000-05-02T10:05:00        Temp Water
# 1         2000-05-02T10:05:00        StrepF PMF
# 2         2000-05-02T10:05:00        Cond @ 20C
# 3         2000-05-02T10:05:00        F Coli Pre
# 4         2000-05-02T10:05:00      WethYdy Temp
# ...                       ...               ...
# 7308646   2025-03-07T12:39:00       Oxygen Diss
# 7308647   2025-03-07T12:39:00         Flow Type
# 7308648   2025-03-07T12:39:00       Alky pH 4.5
# 7308649   2025-03-07T12:39:00      Orthophospht
# 7308650   2025-03-07T12:39:00      C - Org Filt
#
#                             determinand.definition  determinand.notation  \
# 0                             Temperature of Water                    76
# 1         Streptococci : Faecal : Presumptive : MF                  6423
# 2                             Conductivity at 20 C                    62
# 3             Coliforms, Faecal : Presumptive : MF                  3461
# 4        Weather : Temperature : Previous 24 hours                  3026
# ...                                            ...                   ...
# 7308646                    Oxygen, Dissolved as O2                  9924
# 7308647                                  Flow Type                  2896
# 7308648              Alkalinity to pH 4.5 as CaCO3                   162
# 7308649              Orthophosphate, reactive as P                   180
# 7308650   Carbon, Organic, Dissolved as C :- {DOC}                   301
#
#         resultQualifier.notation    result  \
# 0                            NaN    10.000
# 1                            NaN   290.000
# 2                            NaN   421.000
# 3                            NaN  2600.000
# 4                            NaN     4.000
# ...                          ...       ...
# 7308646                      NaN    11.100
# 7308647                      NaN     5.000
# 7308648                      NaN    22.000
# 7308649                      NaN     0.014
# 7308650                      NaN     3.300
#
#          codedResultInterpretation.interpretation determinand.unit.label  \
# 0                                             NaN                    cel
# 1                                             NaN               no/100ml
# 2                                             NaN                  us/cm
# 3                                             NaN               no/100ml
# 4                                             NaN                  coded
# ...                                           ...                    ...
# 7308646                                       NaN                   mg/l
# 7308647                                       NaN                  coded
# 7308648                                       NaN                   mg/l
# 7308649                                       NaN                   mg/l
# 7308650                                       NaN                   mg/l
#
#         sample.sampledMaterialType.label  sample.isComplianceSample  \
# 0          RIVER / RUNNING SURFACE WATER                      False
# 1          RIVER / RUNNING SURFACE WATER                      False
# 2          RIVER / RUNNING SURFACE WATER                      False
# 3          RIVER / RUNNING SURFACE WATER                      False
# 4          RIVER / RUNNING SURFACE WATER                      False
# ...                                  ...                        ...
# 7308646    RIVER / RUNNING SURFACE WATER                      False
# 7308647    RIVER / RUNNING SURFACE WATER                      False
# 7308648    RIVER / RUNNING SURFACE WATER                      False
# 7308649    RIVER / RUNNING SURFACE WATER                      False
# 7308650    RIVER / RUNNING SURFACE WATER                      False
#
#                                       sample.purpose.label  \
# 0        ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 1        ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 2        ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 3        ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 4        ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# ...                                                    ...
# 7308646               MONITORING  (NATIONAL AGENCY POLICY)
# 7308647               MONITORING  (NATIONAL AGENCY POLICY)
# 7308648               MONITORING  (NATIONAL AGENCY POLICY)
# 7308649               MONITORING  (NATIONAL AGENCY POLICY)
# 7308650               MONITORING  (NATIONAL AGENCY POLICY)
#
#          sample.samplingPoint.easting  sample.samplingPoint.northing
# 0                              334223                          92129
# 1                              334223                          92129
# 2                              334223                          92129
# 3                              334223                          92129
# 4                              334223                          92129
# ...                               ...                            ...
# 7308646                        275241                          83915
# 7308647                        275241                          83915
# 7308648                        275241                          83915
# 7308649                        275241                          83915
# 7308650                        275241                          83915
#
# [7308651 rows x 17 columns]

# %%
df_water.to_csv(dir_files+region_code+"WaterQuality.csv")
